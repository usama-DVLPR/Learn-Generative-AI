# %%
num = 2

# %%
print(num)
# Out:
# 2

# %%
type(True)
# Out:
# bool

# %%
type(num)
# Out:
# int

# %%
my_str = 'Usama Hameed'

# %%
len(my_str)
# Out:
# 12

# %%
list = [1,2,3,5,67,8]
type(list)
# Out:
# list

# %%
list
# Out:
# [1, 2, 3, 5, 67, 8]

# %%
list[2]
# Out:
# 3

# %%
 len(list)
# Out:
# 6
